# %% [markdown]
# EXP-8 : Visulize the frequency distribution of ages in a dataset using a histogram.
#
# OUTPUT:  A histogram showing age distribution.

# %% [markdown]
# 1. Import the necessary libraries: `pandas` for data handling and `matplotlib.pyplot` for plotting.
# 2. Create a sample dataset with age data in a dictionary and convert it into a pandas DataFrame.
# 3. Use `plt.hist()` to create a histogram of the 'Age' column, specifying the number of bins and customizing the color and edge of the bars.
# 4. Add a title, x-axis label, and y-axis label to the plot for better understanding.
# 5. Display the plot using `plt.show()` and enable grid lines with `plt.grid(True)`.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Sample dataset with age data
data = {
    'Age': [23, 45, 18, 34, 25, 40, 28, 22, 60, 55, 30, 36, 24, 50, 19, 31, 45, 62, 35, 29]
}

# Convert data into a pandas DataFrame
df = pd.DataFrame(data)

# Plot histogram
plt.figure(figsize=(10, 6))
plt.hist(df['Age'], bins=10, color='skyblue', edgecolor='black')

# Add labels and title
plt.title('Age Distribution', fontsize=14)
plt.xlabel('Age', fontsize=12)
plt.ylabel('Frequency', fontsize=12)

# Show the plot
plt.grid(True)
plt.show()
